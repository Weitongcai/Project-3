# %%
import pandas as pd
import numpy as np
import requests
import pprint
# Impor the OpenWeatherMap API key
from api_keys import yelp_api_key

# %% [markdown]
# ## Take 50 samples in Toronto

# %%
# Set the API base URL and endpoint
base_url = "https://api.yelp.com/v3"
endpoint = "/businesses/search"

headers = {
    "Authorization": f"Bearer {yelp_api_key}"
}

params = {
    "location": "Toronto", 
    "offset": 0,
    "price": "1,2,3,4",
    "limit": 50  
}

response = requests.get(base_url + endpoint, headers=headers, params=params)
Toronto_data = response.json()

pprint.pprint(Toronto_data)
# Out:
# {'businesses': [{'alias': 'pai-northern-thai-kitchen-toronto-5',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 43.64784, 'longitude': -79.38872},
#                  'display_phone': '+1 416-901-4724',
#                  'distance': 3009.3347434869856,
#                  'id': 'r_BrIgzYcwo1NAuG9dLbpg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9QruaHywVEtolW9ELorHpA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '18 Duncan Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['18 Duncan Street',
#                                                   'Toronto, ON M5H 3G8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5H 3G8'},
#                  'name': 'Pai Northern Thai Kitchen',
#                  'phone': '+14169014724',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 3398,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pai-northern-thai-kitchen-toronto-5?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'richmond-station-toronto',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 43.6513729,
#                                  'longitude': -79.379285},
#                  'display_phone': '+1 647-748-1444',
#                  'distance': 2911.814072486624,
#                  'id': 'mZRKH9ngRY92bI_irrHq6w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/agCQCtFg1pwV4WRBBw8CAg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Richmond Street W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['1 Richmond Street W',
#                                                   'Toronto, ON M5H 3W4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5H 3W4'},
#                  'name': 'Richmond Station',
#                  'phone': '+16477481444',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 887,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/richmond-station-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'byblos-toronto-2',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'mideastern',
#                                  'title': 'Middle Eastern'}],
#                  'coordinates': {'latitude': 43.647546,
#                                  'longitude': -79.388123},
#                  'display_phone': '+1 647-660-0909',
#                  'distance': 3054.112033364548,
#                  'id': 'Yl2TN9c23ZGLUBSD9ks5Uw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ciuAYgyPtC7HtljXC4nEnw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '11 Duncan Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['11 Duncan Street',
#                                                   'Toronto, ON M5V 3M2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 3M2'},
#                  'name': 'Byblos',
#                  'phone': '+16476600909',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 898,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/byblos-toronto-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'yasu-toronto-8',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 43.66269, 'longitude': -79.40314},
#                  'display_phone': '+1 416-477-2361',
#                  'distance': 1382.2242471833936,
#                  'id': 'q9_gLvTNf11etVxbH7JY0Q',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hp7IbcPV6iJV2jsS0qJDyQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '81 Harbord Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['81 Harbord Street',
#                                                   'Toronto, ON M5S 1G4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5S 1G4'},
#                  'name': 'Yasu',
#                  'phone': '+14164772361',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 424,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/yasu-toronto-8?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'kinka-izakaya-original-toronto-4',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 43.66042406856627,
#                                  'longitude': -79.37890046282942},
#                  'display_phone': '+1 416-977-0999',
#                  'distance': 2109.9595120354325,
#                  'id': 'RtUvSWO_UZ8V3Wpj0n077w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nHFVveLBqeiCGy12R2CnRA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '398 Church Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['398 Church Street',
#                                                   'Toronto, ON M5B 2A2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5B 2A2'},
#                  'name': 'KINKA IZAKAYA ORIGINAL',
#                  'phone': '+14169770999',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1804,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kinka-izakaya-original-toronto-4?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'josos-toronto',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 43.6751099,
#                                  'longitude': -79.39607},
#                  'display_phone': '+1 416-925-1903',
#                  'distance': 104.33812261272229,
#                  'id': 'K3NW8TEu4QRQvFvHer8v4A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GJR1cFgaDp7txryGe5shTQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '202 Davenport Road',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['202 Davenport Road',
#                                                   'Toronto, ON M5R 1J2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5R 1J2'},
#                  'name': "Joso's",
#                  'phone': '+14169251903',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 171,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/josos-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'gusto-101-toronto',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 43.645002131066,
#                                  'longitude': -79.400309337027},
#                  'display_phone': '+1 416-504-9669',
#                  'distance': 3267.8432435946374,
#                  'id': 'B70iTJjcPkuYn8ouUewWgw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nVqA7kB5QuXBWX8Nq9-nQQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '101 Portland Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['101 Portland Street',
#                                                   'Toronto, ON M5V 2N3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 2N3'},
#                  'name': 'Gusto 101',
#                  'phone': '+14165049669',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1123,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gusto-101-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'ristorante-sotto-sotto-toronto',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 43.67374, 'longitude': -79.39646},
#                  'display_phone': '+1 416-962-0011',
#                  'distance': 67.10055450161477,
#                  'id': 'u71djaZjecGVU1MqMevQ4g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r5WuvmqtEYjOZZjVtLlhmw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '120 Avenue Road',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['120 Avenue Road',
#                                                   'Toronto, ON M5R 2H4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5R 2H4'},
#                  'name': 'Ristorante Sotto Sotto',
#                  'phone': '+14169620011',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 127,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ristorante-sotto-sotto-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'osteria-giulia-toronto',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 43.67431, 'longitude': -79.39668},
#                  'display_phone': '+1 416-964-8686',
#                  'distance': 19.22116521243309,
#                  'id': '5XVE1NtoMNbXJJcLTj1qeA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JJIEMnULhMXhgP1ClV8n9A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '134 Avenue Road',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['134 Avenue Road',
#                                                   'Toronto, ON M5R 2H6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5R 2H6'},
#                  'name': 'Osteria Giulia',
#                  'phone': '+14169648686',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 30,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/osteria-giulia-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'canoe-toronto-2',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 43.646954,
#                                  'longitude': -79.382159},
#                  'display_phone': '+1 416-364-0054',
#                  'distance': 3259.5714701039,
#                  'id': 'JMiaNitMzMbJm6Kh0RbT5A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tlQLlDmbY2EjEpxV_UALGw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '66 Wellington Street  W',
#                               'address2': '54th Floor',
#                               'address3': 'TD Bank Tower',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['66 Wellington Street  W',
#                                                   '54th Floor',
#                                                   'TD Bank Tower',
#                                                   'Toronto, ON M5K 1H6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5K 1H6'},
#                  'name': 'Canoe',
#                  'phone': '+14163640054',
#                  'price': '$$$$',
#                  'rating': 4.0,
#                  'review_count': 745,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/canoe-toronto-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'scaramouche-restaurant-pasta-bar-and-grill-toronto',
#                  'categories': [{'alias': 'french', 'title': 'French'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 43.68155, 'longitude': -79.39991},
#                  'display_phone': '+1 416-961-8011',
#                  'distance': 831.4897662752536,
#                  'id': '_T7f2wUgNlJqxsR-cR89SQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XeRT7r5JbhUSr2a6zSIqYg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Benvenuto Place',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['1 Benvenuto Place',
#                                                   'Toronto, ON M4V 2L1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M4V 2L1'},
#                  'name': 'Scaramouche Restaurant Pasta Bar & Grill',
#                  'phone': '+14169618011',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 332,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/scaramouche-restaurant-pasta-bar-and-grill-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'her-fathers-cider-bar-and-kitchen-toronto',
#                  'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 43.66232, 'longitude': -79.40453},
#                  'display_phone': '+1 647-347-7747',
#                  'distance': 1467.9214664770316,
#                  'id': '47wBHgBwQ8_70sjmXow_1g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1ElufiJeX8BzW-oSEqffpQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '119 Harbord Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['119 Harbord Street',
#                                                   'Toronto, ON M5S 1G7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5S 1G7'},
#                  'name': "Her Father's Cider Bar & Kitchen",
#                  'phone': '+16473477747',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 188,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/her-fathers-cider-bar-and-kitchen-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'jacobs-and-co-steakhouse-toronto',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#                  'coordinates': {'latitude': 43.64539876116,
#                                  'longitude': -79.3980279011192},
#                  'display_phone': '+1 416-366-0200',
#                  'distance': 3213.132106562395,
#                  'id': 'ZumOnWbstgsIE6bJlxw0_Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QnuGwNzr3C87cEy_uw9sMw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '12 Brant Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['12 Brant Street',
#                                                   'Toronto, ON M5V 1K4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 1K4'},
#                  'name': 'Jacobs & Co. Steakhouse',
#                  'phone': '+14163660200',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 610,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jacobs-and-co-steakhouse-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'lee-toronto-6',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 43.64723, 'longitude': -79.39931},
#                  'display_phone': '+1 416-504-7867',
#                  'distance': 3014.6996978970706,
#                  'id': 'snw9iNNLpFYZeHotW00uVA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zx0aFKfzKVihu3dn1POGSA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '497 Richmond St W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['497 Richmond St W',
#                                                   'Toronto, ON M5V 1Y3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 1Y3'},
#                  'name': 'Lee',
#                  'phone': '+14165047867',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 710,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/lee-toronto-6?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'rasa-toronto',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'}],
#                  'coordinates': {'latitude': 43.6627752,
#                                  'longitude': -79.4039682},
#                  'display_phone': '+1 647-350-8221',
#                  'distance': 1402.7329472369408,
#                  'id': 'eKznX8VTfcQrjCqXpeobiw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wPprWzf9PTM62UYDgaobeA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '196 Robert Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['196 Robert Street',
#                                                   'Toronto, ON M5S 2K8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5S 2K8'},
#                  'name': 'Rasa',
#                  'phone': '+16473508221',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 321,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/rasa-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'alo-restaurant-toronto',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'french', 'title': 'French'}],
#                  'coordinates': {'latitude': 43.64851, 'longitude': -79.39584},
#                  'display_phone': '+1 416-260-2222',
#                  'distance': 2861.5378545315702,
#                  'id': 'EEIz44ewHhOKmfTloAK13g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wa3yNQpC4Img1jiAZkTrzw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '163 Spadina Avenue',
#                               'address2': '3rd Floor',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['163 Spadina Avenue',
#                                                   '3rd Floor',
#                                                   'Toronto, ON M5V 2A5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 2A5'},
#                  'name': 'Alo Restaurant',
#                  'phone': '+14162602222',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 335,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/alo-restaurant-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'george-restaurant-toronto-3',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 43.65337263523713,
#                                  'longitude': -79.37432933100068},
#                  'display_phone': '+1 416-863-6006',
#                  'distance': 2945.946687279367,
#                  'id': 'Sk0Ycurq7D083Qs8x65b_Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3IJ79pmaRXapc8MfZU820Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '111 Queen Street E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['111 Queen Street E',
#                                                   'Toronto, ON M5C 1S2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5C 1S2'},
#                  'name': 'George Restaurant',
#                  'phone': '+14168636006',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 295,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/george-restaurant-toronto-3?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'ramen-isshin-toronto',
#                  'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#                  'coordinates': {'latitude': 43.65634, 'longitude': -79.40689},
#                  'display_phone': '+1 416-367-4013',
#                  'distance': 2156.2378719884887,
#                  'id': 'crstB-H5rOfbXhV8pX0e6g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LvnYnumInn7dmCewmQsU3w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '421 College Street',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['421 College Street',
#                                                   'Toronto, ON M5T 1T1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5T 1T1'},
#                  'name': 'Ramen Isshin',
#                  'phone': '+14163674013',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 804,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ramen-isshin-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'kinka-izakaya-annex-toronto-2',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 43.665157,
#                                  'longitude': -79.410658},
#                  'display_phone': '+1 647-343-1101',
#                  'distance': 1506.0784402358188,
#                  'id': 'CN5nuUQod0f8g3oh99qq0w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/43RRSeAOPBk7r6qIzDfLnQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '559 Bloor St W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['559 Bloor St W',
#                                                   'Toronto, ON M5S 1Y6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5S 1Y6'},
#                  'name': 'KINKA IZAKAYA ANNEX',
#                  'phone': '+16473431101',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 504,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kinka-izakaya-annex-toronto-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'dzo-viet-eatery-toronto',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 43.65445, 'longitude': -79.39178},
#                  'display_phone': '+1 647-346-8843',
#                  'distance': 2243.910181518081,
#                  'id': 'VS0Tm4uB_oZ7zGcANOl8uw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/whO3DlHwdsPc_cu5BZmv6g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '308 Dundas Street W',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['308 Dundas Street W',
#                                                   'Toronto, ON M5T 1G4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5T 1G4'},
#                  'name': 'Dzo Viet Eatery',
#                  'phone': '+16473468843',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 141,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/dzo-viet-eatery-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'insomnia-restaurant-and-lounge-toronto',
#                  'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'comfortfood',
#                                  'title': 'Comfort Food'}],
#                  'coordinates': {'latitude': 43.665961,
#                                  'longitude': -79.411003},
#                  'display_phone': '+1 416-588-3907',
#                  'distance': 1468.7971044745764,
#                  'id': 'e41TP5cXZqSrz50xCBJqZw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kgiZaD3Il4F5iMfjposs3w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '563 Bloor Street W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['563 Bloor Street W',
#                                                   'Toronto, ON M5S 1Y6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5S 1Y6'},
#                  'name': 'Insomnia Restaurant & Lounge',
#                  'phone': '+14165883907',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1015,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/insomnia-restaurant-and-lounge-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'beerbistro-toronto-3',
#                  'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#                                 {'alias': 'beerbar', 'title': 'Beer Bar'},
#                                 {'alias': 'comfortfood',
#                                  'title': 'Comfort Food'}],
#                  'coordinates': {'latitude': 43.649467134996364,
#                                  'longitude': -79.3771696548727},
#                  'display_phone': '+1 416-861-9872',
#                  'distance': 3179.9774798541725,
#                  'id': 'O-uIEuv7JLUHajkemx_sVw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OPZ0QcowdI783fu7D0jcSg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '18 King Street E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['18 King Street E',
#                                                   'Toronto, ON M5C 1C4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5C 1C4'},
#                  'name': 'Beerbistro',
#                  'phone': '+14168619872',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 678,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/beerbistro-toronto-3?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'zakkushi-on-carlton-toronto',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 43.66343, 'longitude': -79.37062},
#                  'display_phone': '+1 647-352-9455',
#                  'distance': 2425.741525051165,
#                  'id': 'ALkOqlWODyxPg5VSp0HLrg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NxgVVhj_SXGdJxFgD0IVJg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '193 Carlton Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['193 Carlton Street',
#                                                   'Toronto, ON M5A 2K9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5A 2K9'},
#                  'name': 'Zakkushi On Carlton',
#                  'phone': '+16473529455',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 328,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/zakkushi-on-carlton-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'antler-kitchen-and-bar-toronto',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 43.64985, 'longitude': -79.43059},
#                  'display_phone': '+1 647-345-8300',
#                  'distance': 3852.7090187319895,
#                  'id': 'qPVqfJAzC8APF8aWGBtFRA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_T3Ghy_vzxqNS3rdKv-PYQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1454 Dundas Street West',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['1454 Dundas Street West',
#                                                   'Toronto, ON M6J 1Y6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M6J 1Y6'},
#                  'name': 'Antler Kitchen & Bar',
#                  'phone': '+16473458300',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 289,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/antler-kitchen-and-bar-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'aloette-toronto-3',
#                  'categories': [{'alias': 'french', 'title': 'French'},
#                                 {'alias': 'bistros', 'title': 'Bistros'},
#                                 {'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 43.64855831176563,
#                                  'longitude': -79.395963},
#                  'display_phone': '+1 416-260-3444',
#                  'distance': 2861.1678709256976,
#                  'id': 'uPa5hrWmHm0n1l4MSyVMGQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TmD4IRy955ucg7fHyOF20Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '163 Spadina Avenue',
#                               'address2': '1st Floor',
#                               'address3': None,
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['163 Spadina Avenue',
#                                                   '1st Floor',
#                                                   'Toronto, ON M5V 2L6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 2L6'},
#                  'name': 'Aloette',
#                  'phone': '+14162603444',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 287,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/aloette-toronto-3?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'bar-raval-toronto',
#                  'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 43.6558432,
#                                  'longitude': -79.4099433},
#                  'display_phone': '+1 647-344-8001',
#                  'distance': 2306.076541452038,
#                  'id': '41o1FUbCYKJv2djtnlkzlg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AyOwAeFcSl8zvBeJ0HxN8A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '505 College Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['505 College Street',
#                                                   'Toronto, ON M6G 2J3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M6G 2J3'},
#                  'name': 'Bar Raval',
#                  'phone': '+16473448001',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 319,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bar-raval-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'planta-yorkville-toronto-10',
#                  'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 43.67028, 'longitude': -79.38945},
#                  'display_phone': '+1 647-812-1221',
#                  'distance': 745.4186614241825,
#                  'id': 'JG9UpsFR6hrqQqsKh_RyaQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PZeryEMsHfd2gxRvB3iyhA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1221 Bay Street',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['1221 Bay Street',
#                                                   'Toronto, ON M5R 3P5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5R 3P5'},
#                  'name': 'PLANTA Yorkville',
#                  'phone': '+16478121221',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 500,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/planta-yorkville-toronto-10?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'seven-lives-tacos-y-mariscos-toronto',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 43.6544903,
#                                  'longitude': -79.4008299},
#                  'display_phone': '+1 416-393-4636',
#                  'distance': 2225.514408873836,
#                  'id': 'iGEvDk6hsizigmXhDKs2Vg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N_kER2ViaxhP6i7SDlIIOg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '72 Kensington Avenue',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['72 Kensington Avenue',
#                                                   'Toronto, ON M5T 2K1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5T 2K1'},
#                  'name': 'Seven Lives Tacos y Mariscos',
#                  'phone': '+14163934636',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1470,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/seven-lives-tacos-y-mariscos-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'khao-san-road-toronto',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 43.646412027881496,
#                                  'longitude': -79.39361985450327},
#                  'display_phone': '+1 647-352-5773',
#                  'distance': 3109.667028077413,
#                  'id': 'aLcFhMe6DDJ430zelCpd2A',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ltk9xRcD5CusiPNJGMwogw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '11 Charlotte Street',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['11 Charlotte Street',
#                                                   'Toronto, ON M5V 2H5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 2H5'},
#                  'name': 'Khao San Road',
#                  'phone': '+16473525773',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1700,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/khao-san-road-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'chubbys-jamaican-kitchen-toronto',
#                  'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#                  'coordinates': {'latitude': 43.64532, 'longitude': -79.40066},
#                  'display_phone': '+1 416-792-8105',
#                  'distance': 3233.087088903006,
#                  'id': 'h8vVxwP6FnlkRDONKBHT-w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1Vwt13a0XtAcDsFZ-meQDg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '104 Portland Street',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['104 Portland Street',
#                                                   'Toronto, ON M5V 2N2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 2N2'},
#                  'name': "Chubby's Jamaican Kitchen",
# ...
#                 {'alias': 'jabistro-toronto-2',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 43.64980116402221,
#                                  'longitude': -79.3881706},
#                  'display_phone': '+1 647-748-0222',
#                  'distance': 2809.650628209266,
#                  'id': 'Qmwfg-PtYuCo5Q_IwcA_HQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AcTjxOEi_DeBj3Eg9bj1zQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '222 Richmond Street W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['222 Richmond Street W',
#                                                   'Toronto, ON M5V 1V6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 1V6'},
#                  'name': 'JaBistro',
#                  'phone': '+16477480222',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 586,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jabistro-toronto-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'ikkousha-ramen-toronto-4',
#                  'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#                  'coordinates': {'latitude': 43.650915297488666,
#                                  'longitude': -79.38922205031365},
#                  'display_phone': '+1 416-901-2249',
#                  'distance': 2669.1694848989705,
#                  'id': 'BWCfyBdnTvuXp6A_8wt8cA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q-Sx02Qg6XgkEGUqqRV_Kw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '249 Queen Street W',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['249 Queen Street W',
#                                                   'Toronto, ON M5V 1Z4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 1Z4'},
#                  'name': 'Ikkousha Ramen',
#                  'phone': '+14169012249',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 298,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ikkousha-ramen-toronto-4?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'bar-isabel-toronto',
#                  'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#                                 {'alias': 'tapas', 'title': 'Tapas Bars'}],
#                  'coordinates': {'latitude': 43.654631,
#                                  'longitude': -79.4207738},
#                  'display_phone': '+1 416-532-2222',
#                  'distance': 2912.718682204373,
#                  'id': 'q5xrVJ4kivx_yEfJeOKNYQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nk63u0JvadnPyjA_MHxUcg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '797 College Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['797 College Street',
#                                                   'Toronto, ON M6G 1C7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M6G 1C7'},
#                  'name': 'Bar Isabel',
#                  'phone': '+14165322222',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 467,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/bar-isabel-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'cactus-club-cafe-toronto',
#                  'categories': [{'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'},
#                                 {'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 43.64950420768667,
#                                  'longitude': -79.38251803088575},
#                  'display_phone': '+1 647-748-2025',
#                  'distance': 2985.713992761241,
#                  'id': 'yY3jNsrpCyKTqQuRuLV8gw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1fob77kJSVUCa_IgnubnNQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '77 Adelaide Street W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['77 Adelaide Street W',
#                                                   'Toronto, ON M5H 1P9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5H 1P9'},
#                  'name': 'Cactus Club Cafe',
#                  'phone': '+16477482025',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 591,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/cactus-club-cafe-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'mira-toronto',
#                  'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#                  'coordinates': {'latitude': 43.64417, 'longitude': -79.39639},
#                  'display_phone': '+1 647-951-3331',
#                  'distance': 3359.763701463973,
#                  'id': 'KpEu3vvj1ruoID0T3lmD4Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jHspzrCPem1pJ3ttSYyL0w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '420A Wellington Street W',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['420A Wellington Street W',
#                                                   'Toronto, ON M5V 1E3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5V 1E3'},
#                  'name': 'Mira',
#                  'phone': '+16479513331',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 263,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mira-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'blu-ristorante-toronto-5',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 43.67237, 'longitude': -79.39586},
#                  'display_phone': '+1 416-921-1471',
#                  'distance': 225.01733033461625,
#                  'id': 'CNPnbJlMmCx08geOvDmH7A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/En6lgGFAKoc43pXrLTREuw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '90 Avenue Road',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['90 Avenue Road',
#                                                   'Toronto, ON M5R 2H2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5R 2H2'},
#                  'name': 'Blu Ristorante',
#                  'phone': '+14169211471',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 173,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/blu-ristorante-toronto-5?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'lamesa-filipino-kitchen-toronto',
#                  'categories': [{'alias': 'filipino', 'title': 'Filipino'}],
#                  'coordinates': {'latitude': 43.682297,
#                                  'longitude': -79.423948},
#                  'display_phone': '+1 647-343-1110',
#                  'distance': 2356.6307655640967,
#                  'id': '-ICGmF2qUVKdvOehVNgPbg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3AZeyIRmrH2KgQYn_Ag_8A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '634 St Clair Avenue W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['634 St Clair Avenue W',
#                                                   'Toronto, ON M6C 1A9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M6C 1A9'},
#                  'name': 'Lamesa Filipino Kitchen',
#                  'phone': '+16473431110',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 366,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/lamesa-filipino-kitchen-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'playa-cabana-toronto',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 43.6759577692695,
#                                  'longitude': -79.4011840224266},
#                  'display_phone': '+1 416-929-3911',
#                  'distance': 397.3648796523013,
#                  'id': 'O_UC_izJXcAmkm6HlEyGSA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7XPqyMO4KYppNbsKccwqyA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '111 Dupont Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['111 Dupont Street',
#                                                   'Toronto, ON M5R 1V4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5R 1V4'},
#                  'name': 'Playa Cabana',
#                  'phone': '+14169293911',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 471,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/playa-cabana-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'kinton-ramen-toronto-16',
#                  'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 43.6603113,
#                                  'longitude': -79.3789004},
#                  'display_phone': '+1 647-348-8555',
#                  'distance': 2105.6460747111155,
#                  'id': '4Ua5_CI0rKq3ar5hUTUprw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TjiAOp4_as2HWhYTj6jWkw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '396 Church Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['396 Church Street',
#                                                   'Toronto, ON M5B 2A2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5B 2A2'},
#                  'name': 'KINTON RAMEN',
#                  'phone': '+16473488555',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 225,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kinton-ramen-toronto-16?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'the-queen-and-beaver-public-house-toronto',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'british', 'title': 'British'}],
#                  'coordinates': {'latitude': 43.65734, 'longitude': -79.38334},
#                  'display_phone': '+1 647-347-2712',
#                  'distance': 2174.851552413904,
#                  'id': 'qaNt4vtVdge_S68DVjw5Jg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SJyDejN1DucWx4mrTwHmHw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '35 Elm Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['35 Elm Street',
#                                                   'Toronto, ON M5G 1H1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M5G 1H1'},
#                  'name': 'The Queen And Beaver Public House',
#                  'phone': '+16473472712',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 409,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-queen-and-beaver-public-house-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'}],
#  'region': {'center': {'latitude': 43.67428196976998,
#                        'longitude': -79.39682006835938}},
#  'total': 5700}

# %%
# Create empty lists to store the results
names = []
ratings = []
prices = []
categories = []
display_addresses = []
review_counts = []
latitudes = []
longitudes = []

# Loop through each business and extract the desired information
for business in Toronto_data["businesses"]:
    names.append(business["name"])
    ratings.append(business["rating"])
    prices.append(business.get("price", "N/A"))
    categories.append(", ".join([category["title"] for category in business["categories"]]))
    display_addresses.append(", ".join(business["location"]["display_address"]))
    review_counts.append(business["review_count"])
    latitudes.append(business["coordinates"]["latitude"])
    longitudes.append(business["coordinates"]["longitude"])

# Create a dataframe from the extracted information
Toronto_df = pd.DataFrame({
    "Name": names,
    "Rating": ratings,
    "Price": prices,
    "Categories": categories,
    "Address": display_addresses,
    "Reviews": review_counts,
    "Latitude": latitudes,
    "Longitude": longitudes
}, index=range(1, len(Toronto_data["businesses"]) + 1))

# Print the dataframe
Toronto_df.head()
# Out:
#                         Name  Rating Price                     Categories  \
# 1  Pai Northern Thai Kitchen     4.5    $$                           Thai
# 2           Richmond Station     4.5   $$$                 Canadian (New)
# 3                     Byblos     4.5  $$$$  Mediterranean, Middle Eastern
# 4                       Yasu     4.5  $$$$           Japanese, Sushi Bars
# 5     KINKA IZAKAYA ORIGINAL     4.0    $$                 Japanese, Pubs
#
#                                             Address  Reviews   Latitude  \
# 1     18 Duncan Street, Toronto, ON M5H 3G8, Canada     3398  43.647840
# 2  1 Richmond Street W, Toronto, ON M5H 3W4, Canada      887  43.651373
# 3     11 Duncan Street, Toronto, ON M5V 3M2, Canada      898  43.647546
# 4    81 Harbord Street, Toronto, ON M5S 1G4, Canada      424  43.662690
# 5    398 Church Street, Toronto, ON M5B 2A2, Canada     1804  43.660424
#
#    Longitude
# 1 -79.388720
# 2 -79.379285
# 3 -79.388123
# 4 -79.403140
# 5 -79.378900

# %%
Toronto_df.dtypes
# Out:
# Name           object
# Rating        float64
# Price          object
# Categories     object
# Address        object
# Reviews         int64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
# Save the DataFrame 
Toronto_df.to_csv('Toronto.csv', index=False)

# %% [markdown]
# ## Take 50 samples in Markham

# %%
# Set the API base URL and endpoint
base_url = "https://api.yelp.com/v3"
endpoint = "/businesses/search"

headers = {
    "Authorization": f"Bearer {yelp_api_key}"
}

params = {
    "location": "Markham", 
    "offset": 0,
    "price": "1,2,3,4",
    "limit": 50  
}

response = requests.get(base_url + endpoint, headers=headers, params=params)
Markham_data = response.json()

pprint.pprint(Markham_data)
# Out:
# {'businesses': [{'alias': 'smash-kitchen-and-bar-unionville',
#                  'categories': [{'alias': 'comfortfood',
#                                  'title': 'Comfort Food'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 43.85912, 'longitude': -79.31473},
#                  'display_phone': '+1 905-940-2000',
#                  'distance': 263.00098354015455,
#                  'id': 'wxL9wgxLeuMMfI6SAXIzJw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c4YJ24lSDoN_3dMFC7CihA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4261 Highway 7 E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Unionville',
#                               'country': 'CA',
#                               'display_address': ['4261 Highway 7 E',
#                                                   'Unionville, ON L3R 9W6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 9W6'},
#                  'name': 'Smash Kitchen & Bar',
#                  'phone': '+19059402000',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 860,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smash-kitchen-and-bar-unionville?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'nextdoor-restaurant-markham-3',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'}],
#                  'coordinates': {'latitude': 43.8654, 'longitude': -79.31005},
#                  'display_phone': '+1 905-604-6983',
#                  'distance': 1020.4011216025576,
#                  'id': '-Lgj3gdQZiVngAEc1yALzw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lnYwvQWkVDnz1Y5Blkp8ng/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '139 Main Street Unionville',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['139 Main Street Unionville',
#                                                   'Markham, ON L3R 2G6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 2G6'},
#                  'name': 'NextDoor Restaurant',
#                  'phone': '+19056046983',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 557,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/nextdoor-restaurant-markham-3?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'alchemy-coffee-markham-3',
#                  'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 43.860536887326894,
#                                  'longitude': -79.312339},
#                  'display_phone': '+1 905-604-6622',
#                  'distance': 451.44182753105804,
#                  'id': '5XVabANkehj7oH-Z7YZkwg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WPMoJzYOYwlaI8Ay0blJvQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4361 Highway 7 E',
#                               'address2': 'Unit 1',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['4361 Highway 7 E',
#                                                   'Unit 1',
#                                                   'Markham, ON L3R 1M1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 1M1'},
#                  'name': 'Alchemy Coffee',
#                  'phone': '+19056046622',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 605,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/alchemy-coffee-markham-3?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'azyun-restaurant-markham',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'tapas', 'title': 'Tapas Bars'}],
#                  'coordinates': {'latitude': 43.8789007046804,
#                                  'longitude': -79.2611804232001},
#                  'display_phone': '+1 905-554-1666',
#                  'distance': 4927.004199413768,
#                  'id': '4FEb2SzmU_l7SCQAbvW5Hg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jq-kVmLxJR-gdSV6s3jkGg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '144 Main Street N',
#                               'address2': 'Unit 17',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['144 Main Street N',
#                                                   'Unit 17',
#                                                   'Markham, ON L3P 5T3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3P 5T3'},
#                  'name': 'Azyun Restaurant',
#                  'phone': '+19055541666',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 257,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/azyun-restaurant-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'ruths-chris-steak-house-markham',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'lounges', 'title': 'Lounges'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 43.8495534,
#                                  'longitude': -79.3245362},
#                  'display_phone': '+1 647-794-0170',
#                  'distance': 1140.4866899266913,
#                  'id': 'FglXSTFdlSM4WoCcEf01tw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tl_XCJADQGNUuBWxYFobqg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '170 Enterprise Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['170 Enterprise Blvd',
#                                                   'Markham, ON L6G 0E6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 0E6'},
#                  'name': "Ruth's Chris Steak House",
#                  'phone': '+16477940170',
#                  'price': '$$$$',
#                  'rating': 4.0,
#                  'review_count': 108,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ruths-chris-steak-house-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'good-catch-cafe-markham',
#                  'categories': [{'alias': 'hkcafe',
#                                  'title': 'Hong Kong Style Cafe'}],
#                  'coordinates': {'latitude': 43.84966273452512,
#                                  'longitude': -79.32241793707824},
#                  'display_phone': '+1 905-940-3232',
#                  'distance': 1017.2138688074815,
#                  'id': 'sACnL92B89x7BtVjnz9sVA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8mp2tryMdHGRIx1MGQntiQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '179 Enterprise Blvd',
#                               'address2': 'Unit 109',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['179 Enterprise Blvd',
#                                                   'Unit 109',
#                                                   'Markham, ON L6G 0A2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 0A2'},
#                  'name': 'Good Catch Cafe',
#                  'phone': '+19059403232',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 132,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/good-catch-cafe-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'chiang-rai-thai-kitchen-and-bar-markham',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 43.84265, 'longitude': -79.30605},
#                  'display_phone': '+1 905-604-8424',
#                  'distance': 1719.2593954373397,
#                  'id': 'n84zloJr2-4OXmOGS7mG6A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PII24RKiOhbjIWFXCLZ-9Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7750 Kennedy Rd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['7750 Kennedy Rd',
#                                                   'Markham, ON L3R 0A7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 0A7'},
#                  'name': 'Chiang Rai Thai Kitchen and Bar',
#                  'phone': '+19056048424',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 218,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chiang-rai-thai-kitchen-and-bar-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'inspire-restaurant-markham-2',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'burgers', 'title': 'Burgers'}],
#                  'coordinates': {'latitude': 43.87922873459434,
#                                  'longitude': -79.26133878280334},
#                  'display_phone': '+1 905-554-2889',
#                  'distance': 4934.364403588796,
#                  'id': 'htQgj-ANQpZGpIpkkrEmyQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nP3UjiXicCBhMtVNDqmswQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '144 Main Street N',
#                               'address2': 'Unit 1',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['144 Main Street N',
#                                                   'Unit 1',
#                                                   'Markham, ON L3P 5T3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3P 5T3'},
#                  'name': 'Inspire Restaurant',
#                  'phone': '+19055542889',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 524,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/inspire-restaurant-markham-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'kiu-japanese-restaurant-markham',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 43.8496812,
#                                  'longitude': -79.3220427},
#                  'display_phone': '+1 905-513-6368',
#                  'distance': 996.9007726307782,
#                  'id': 'Ro-_PAzq-Rdxl5JhM3WmoA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M1MC2vuT5zbVYI6esWCxGg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '169 Enterprise Boulevard',
#                               'address2': '2nd Floor',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['169 Enterprise Boulevard',
#                                                   '2nd Floor',
#                                                   'Markham, ON L6G 0E7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 0E7'},
#                  'name': 'Kiu Japanese Restaurant',
#                  'phone': '+19055136368',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 393,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kiu-japanese-restaurant-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'draco-markham-markham',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 43.8497519,
#                                  'longitude': -79.3242324},
#                  'display_phone': '+1 905-489-1400',
#                  'distance': 1115.6059089779947,
#                  'id': '9mVkXG2ejmjwyzz9TfaUOA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1_0Ul4nbDFpotz9YNRfuNQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '170 Enterprise Boulevard',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['170 Enterprise Boulevard',
#                                                   'Markham, ON L6G 1B3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 1B3'},
#                  'name': 'Draco Markham',
#                  'phone': '+19054891400',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 110,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/draco-markham-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'fat-ninja-bite-toronto-2',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'korean', 'title': 'Korean'}],
#                  'coordinates': {'latitude': 43.82298649562184,
#                                  'longitude': -79.30644546697775},
#                  'display_phone': '+1 416-321-8866',
#                  'distance': 3810.1140663644746,
#                  'id': 'hPXR-Bi8U-uz6TUViqmGpg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i830m6F7T_-573pcUMajRw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3517 Kennedy Road',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['3517 Kennedy Road',
#                                                   'Toronto, ON M1V 4Y3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M1V 4Y3'},
#                  'name': 'Fat Ninja Bite',
#                  'phone': '+14163218866',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 540,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/fat-ninja-bite-toronto-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'peters-fine-dining-markham-4',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'steak', 'title': 'Steakhouses'}],
#                  'coordinates': {'latitude': 43.8710271,
#                                  'longitude': -79.2682683},
#                  'display_phone': '+1 905-294-9039',
#                  'distance': 4022.0839585693557,
#                  'id': 'cqUky5KFtMlqKaAUYiOnLA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Tg2zx0DGl0veE1r6nFEqqg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5701 Highway 7',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['5701 Highway 7',
#                                                   'Markham, ON L3P 1B1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3P 1B1'},
#                  'name': "Peter's Fine Dining",
#                  'phone': '+19052949039',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 180,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/peters-fine-dining-markham-4?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'kore-chicken-markham',
#                  'categories': [{'alias': 'korean', 'title': 'Korean'},
#                                 {'alias': 'chicken_wings',
#                                  'title': 'Chicken Wings'}],
#                  'coordinates': {'latitude': 43.8558089565539,
#                                  'longitude': -79.3042279215653},
#                  'display_phone': '+1 905-474-9997',
#                  'distance': 824.299766589182,
#                  'id': 'HhX3-S8HTyJ9zF2jk4HCGw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oPvrhtKDIK-rZjvYWMed1w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '28 South Unionville Avenue',
#                               'address2': 'Unit 10',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['28 South Unionville Avenue',
#                                                   'Unit 10',
#                                                   'Markham, ON L3R 4P9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 4P9'},
#                  'name': 'Kore Chicken',
#                  'phone': '+19054749997',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 169,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kore-chicken-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'poke-guys-markham',
#                  'categories': [{'alias': 'poke', 'title': 'Poke'},
#                                 {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#                  'coordinates': {'latitude': 43.8505186,
#                                  'longitude': -79.3256871},
#                  'display_phone': '+1 905-477-7653',
#                  'distance': 1139.4198822758444,
#                  'id': '3U6KnoF3T-xC5wtL-Xc8hQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hZU3tEoXY4ry54GjzJxuyA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8110 Birchmount Road',
#                               'address2': 'Unit 10',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['8110 Birchmount Road',
#                                                   'Unit 10',
#                                                   'Markham, ON L6G 0E3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 0E3'},
#                  'name': 'Poke Guys',
#                  'phone': '+19054777653',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 252,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/poke-guys-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'duo-patisserie-and-cafe-markham',
#                  'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'bakeries', 'title': 'Bakeries'}],
#                  'coordinates': {'latitude': 43.8436699120798,
#                                  'longitude': -79.3778179585934},
#                  'display_phone': '+1 905-763-2232',
#                  'distance': 5288.011715832985,
#                  'id': '2_8_ipfxCRtpXesLdBCqig',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_GLhdmKK9tyT0lkaIbyM0g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '230 Commerce Valley Drive E',
#                               'address2': 'Unit 4',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['230 Commerce Valley Drive E',
#                                                   'Unit 4',
#                                                   'Markham, ON L3T 7Y3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3T 7Y3'},
#                  'name': 'Duo Patisserie & Cafe',
#                  'phone': '+19057632232',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 485,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/duo-patisserie-and-cafe-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'good-catch-boil-house-markham-4',
#                  'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 43.8495966723562,
#                                  'longitude': -79.3224447593093},
#                  'display_phone': '+1 905-940-2881',
#                  'distance': 1024.2770549555416,
#                  'id': 'K1nwSvx14on6eVBbu5E9rA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IOIFJuCGGVlWZwcbicyVtw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '179 Enterprise Boulevard',
#                               'address2': 'Unit M-109',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['179 Enterprise Boulevard',
#                                                   'Unit M-109',
#                                                   'Markham, ON L6G 0A2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 0A2'},
#                  'name': 'Good Catch Boil House',
#                  'phone': '+19059402881',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 470,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/good-catch-boil-house-markham-4?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'sushi-umi-markham',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 43.854169,
#                                  'longitude': -79.337508},
#                  'display_phone': '+1 905-475-1222',
#                  'distance': 1845.1483247149652,
#                  'id': '_JluoRzcAmqPw0azB3cOWA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pjdoaD_D1Qpz8hGzdaQUfg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3621 Highway 7 E',
#                               'address2': 'Unit 104-105',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['3621 Highway 7 E',
#                                                   'Unit 104-105',
#                                                   'Markham, ON L3R 0G6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 0G6'},
#                  'name': 'Sushi Umi',
#                  'phone': '+19054751222',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 39,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sushi-umi-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'jin-korean-noodles-markham',
#                  'categories': [{'alias': 'korean', 'title': 'Korean'},
#                                 {'alias': 'dumplings', 'title': 'Dumplings'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 43.8440031815594,
#                                  'longitude': -79.3779956950391},
#                  'display_phone': '+1 905-764-5922',
#                  'distance': 5291.642839818176,
#                  'id': 'tWFkGCJr2Q34HyFfM4m2Zw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8MJ7KN-SBuE0xhO2VotqdQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '230 Commerce Valley Dr E',
#                               'address2': 'Unit 9',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['230 Commerce Valley Dr E',
#                                                   'Unit 9',
#                                                   'Markham, ON L3T 7Y3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3T 7Y3'},
#                  'name': 'Jin Korean Noodles',
#                  'phone': '+19057645922',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 130,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jin-korean-noodles-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'zen-japanese-restaurant-markham',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 43.8292695759825,
#                                  'longitude': -79.3532338992598},
#                  'display_phone': '+1 905-604-7211',
#                  'distance': 4362.997627065575,
#                  'id': 'Hk1Q874UqawFXq0XzIIBYg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zxdDsCFH2La_LULg9hSHvg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7634 Woodbine Avenue',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['7634 Woodbine Avenue',
#                                                   'Markham, ON L3R 2N2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 2N2'},
#                  'name': 'Zen Japanese Restaurant',
#                  'phone': '+19056047211',
#                  'price': '$$$$',
#                  'rating': 4.0,
#                  'review_count': 190,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/zen-japanese-restaurant-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'good-taste-casserole-rice-unionville-markham',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 43.8612822,
#                                  'longitude': -79.3036518},
#                  'display_phone': '+1 905-604-6691',
#                  'distance': 999.0108977976512,
#                  'id': 'erRdoBvb4ywWky3KMjtVdg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kzYYTn9xhujNpkZtzMZhLg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8390 Kennedy Road',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['8390 Kennedy Road',
#                                                   'Markham, ON L3R 0W4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 0W4'},
#                  'name': 'Good Taste Casserole Rice - Unionville',
#                  'phone': '+19056046691',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 161,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/good-taste-casserole-rice-unionville-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'gyubee-japanese-grill-markham-markham',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 43.81579, 'longitude': -79.34991},
#                  'display_phone': '+1 905-604-1904',
#                  'distance': 5381.485870167937,
#                  'id': '1cGgVvEbuBlW2GDvJ112vA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4CFeCaUqBsBHn1tL_ZsCKw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7100 Woodbine Avenue',
#                               'address2': 'Unit 100',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['7100 Woodbine Avenue',
#                                                   'Unit 100',
#                                                   'Markham, ON L3R 5J2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 5J2'},
#                  'name': 'Gyubee Japanese Grill - Markham',
#                  'phone': '+19056041904',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 565,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gyubee-japanese-grill-markham-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'sansotei-ramen-markham',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 43.8578729,
#                                  'longitude': -79.3241531},
#                  'display_phone': '+1 905-604-7118',
#                  'distance': 748.9641021057283,
#                  'id': 'HTkY1GABYTivk-DKWyrlEw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nzAQJw4A193t8cBbDgvMdA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3987 Highway 7 E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['3987 Highway 7 E',
#                                                   'Markham, ON L3R 5M6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 5M6'},
#                  'name': 'Sansotei Ramen',
#                  'phone': '+19056047118',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 384,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sansotei-ramen-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'chef-88-elite-fine-dining-markham',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 43.83319407911679,
#                                  'longitude': -79.30558283139663},
#                  'display_phone': '+1 905-604-8218',
#                  'distance': 2715.163281133513,
#                  'id': '3R_eIisdqazGFzMLhJh6LA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n1i_2wOSF3bEMuTN0ZbHGA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1661 Denison Street',
#                               'address2': 'Unit T1',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['1661 Denison Street',
#                                                   'Unit T1',
#                                                   'Markham, ON L3R 6E4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 6E4'},
#                  'name': 'Chef 88 Elite Fine Dining',
#                  'phone': '+19056048218',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 96,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chef-88-elite-fine-dining-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'joey-markville-markham',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'},
#                                 {'alias': 'lounges', 'title': 'Lounges'},
#                                 {'alias': 'steak', 'title': 'Steakhouses'}],
#                  'coordinates': {'latitude': 43.86757634830122,
#                                  'longitude': -79.2889818},
#                  'display_phone': '+1 905-604-5639',
#                  'distance': 2367.5581209171633,
#                  'id': 'ID7WUBLnhkdxp8QrjsssZg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lVH21xHQHsj3PPRo-G6osw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1247 - 5000 Highway 7 E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['1247 - 5000 Highway 7 E',
#                                                   'Markham, ON L3R 4M9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 4M9'},
#                  'name': 'Joey Markville',
#                  'phone': '+19056045639',
#                  'price': '$$$',
#                  'rating': 3.5,
#                  'review_count': 311,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/joey-markville-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'hibiki-japanese-cuisine-markham-2',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 43.8611603,
#                                  'longitude': -79.3113251},
#                  'display_phone': '+1 905-604-8418',
#                  'distance': 561.6117674628314,
#                  'id': '6i_EXDHikHWhhDipzMt8rw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vGKfK910EKakR8nGYkMBdw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4450 Highway 7 E',
#                               'address2': 'Unit 3',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['4450 Highway 7 E',
#                                                   'Unit 3',
#                                                   'Markham, ON L3R 1M2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 1M2'},
#                  'name': 'Hibiki Japanese Cuisine',
#                  'phone': '+19056048418',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 187,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hibiki-japanese-cuisine-markham-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'mine-sushi-markham',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 43.8578515,
#                                  'longitude': -79.359668},
#                  'display_phone': '+1 905-470-1688',
#                  'distance': 3629.7392617095,
#                  'id': 'oJYqV8s_Y5y_mNC-38KELA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2gK9fqKMWCrZGGh3wItsPw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8865 Woodbine Avenue',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['8865 Woodbine Avenue',
#                                                   'Markham, ON L3R 5G',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 5G'},
#                  'name': 'MINE Sushi',
#                  'phone': '+19054701688',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 292,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mine-sushi-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'il-postino-unionville',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 43.86747, 'longitude': -79.31264},
#                  'display_phone': '+1 905-940-1555',
#                  'distance': 1205.9452358903595,
#                  'id': 'h_y6FbNPaFbAgeMCD4bcAw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-JFC8giT7Rd80VDcGFzanw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '186 Main Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Unionville',
#                               'country': 'CA',
#                               'display_address': ['186 Main Street',
#                                                   'Unionville, ON L3R 2G9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 2G9'},
#                  'name': 'Il Postino',
#                  'phone': '+19059401555',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 127,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/il-postino-unionville?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'terre-rouge-markham',
#                  'categories': [{'alias': 'french', 'title': 'French'}],
#                  'coordinates': {'latitude': 43.8492899377849,
#                                  'longitude': -79.3259739289411},
#                  'display_phone': '+1 905-597-5668',
#                  'distance': 1244.518669369379,
#                  'id': '7Ym8NVxTO9b1FLGeWGp_Fg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oZrMA7-nu5nnYG4B3aBifA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '162 Enterprise Boulevard',
#                               'address2': 'Unit 1',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['162 Enterprise Boulevard',
#                                                   'Unit 1',
#                                                   'Markham, ON L6G 0A2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 0A2'},
#                  'name': 'Terre Rouge',
#                  'phone': '+19055975668',
#                  'price': '$$$',
#                  'rating': 3.0,
#                  'review_count': 197,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/terre-rouge-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'big-trio-wonton-noodle-markham',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 43.8559113,
#                                  'longitude': -79.3038177},
#                  'display_phone': '+1 905-604-4366',
#                  'distance': 838.9755592304604,
#                  'id': 'rXVLgV4Og3l98OTy6N2dJw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sf18XTVY6wVsLtSdUtfRsA/o.jpg',
#                  'is_closed': False,
# ...
#                  'is_closed': False,
#                  'location': {'address1': '8261 Woodbine Avenue',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['8261 Woodbine Avenue',
#                                                   'Markham, ON L3R 8Z5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 8Z5'},
#                  'name': 'Skyview Fusion Cuisine',
#                  'phone': '+19059449418',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 299,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/skyview-fusion-cuisine-markham-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'nam-2-markham',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 43.86065, 'longitude': -79.30437},
#                  'display_phone': '+1 905-470-1271',
#                  'distance': 911.581322896237,
#                  'id': '3FryxHeiuj770unqTqBUBA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B0cdfvv1TYHCINk0twP4Gw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8380 Kennedy Road',
#                               'address2': 'Unit C7',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['8380 Kennedy Road',
#                                                   'Unit C7',
#                                                   'Markham, ON L3R 9W4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 9W4'},
#                  'name': 'Nam 2',
#                  'phone': '+19054701271',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 152,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/nam-2-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'big-beef-bowl-hand-pulled-noodle-markham',
#                  'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 43.8602599,
#                                  'longitude': -79.30344},
#                  'display_phone': '+1 905-470-7575',
#                  'distance': 956.824259395197,
#                  'id': '8lPxiYChdJdTV24NJvOB3Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AgQpG1iZpv9CnE0OtdBlEw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8362 Kennedy Road',
#                               'address2': '',
#                               'address3': 'New Kennedy Square',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['8362 Kennedy Road',
#                                                   'New Kennedy Square',
#                                                   'Markham, ON L3R 9W5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 9W5'},
#                  'name': 'Big Beef Bowl Hand-Pulled Noodle',
#                  'phone': '+19054707575',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 333,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/big-beef-bowl-hand-pulled-noodle-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'pig-and-chick-markham',
#                  'categories': [{'alias': 'korean', 'title': 'Korean'}],
#                  'coordinates': {'latitude': 43.867704749425755,
#                                  'longitude': -79.31248640386501},
#                  'display_phone': '+1 905-470-8828',
#                  'distance': 1226.2877407992437,
#                  'id': 'VBvZQM1TDV7mLgjlJMPdDA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0V1Xr3peISJUz-GA0MseDw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '190 Main Street',
#                               'address2': 'Unit 2',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['190 Main Street',
#                                                   'Unit 2',
#                                                   'Markham, ON L3R 2G9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 2G9'},
#                  'name': 'Pig & Chick',
#                  'phone': '+19054708828',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 14,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/pig-and-chick-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'the-poké-box-markham',
#                  'categories': [{'alias': 'poke', 'title': 'Poke'},
#                                 {'alias': 'salad', 'title': 'Salad'},
#                                 {'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 43.8505443,
#                                  'longitude': -79.3573068},
#                  'display_phone': '+1 905-305-8820',
#                  'distance': 3540.1409377499053,
#                  'id': 'qcRL3MD7NEP_6NIX8KAVVA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/waBrdGdPG_4YVBqV0Wi9CA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3000 Hwy 7',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['3000 Hwy 7',
#                                                   'Markham, ON L3R 6E1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 6E1'},
#                  'name': 'The Poké Box',
#                  'phone': '+19053058820',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 59,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-pok%C3%A9-box-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'cafe-n-one-markham-2',
#                  'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 43.84643, 'longitude': -79.35775},
#                  'display_phone': '+1 905-604-8511',
#                  'distance': 3657.9317207840904,
#                  'id': 'f0tr5SWCbcUkSj9Q8mITAA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kje3Iu3rX8w-tclDUcJK0A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '8366 woodbine ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['8366 woodbine ave',
#                                                   'Markham, ON L3R 2N8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 2N8'},
#                  'name': 'Cafe N One',
#                  'phone': '+19056048511',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 110,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/cafe-n-one-markham-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'aka-oni-ramen-and-izakaya-scarborough-toronto',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 43.8219855640577,
#                                  'longitude': -79.298919766399},
#                  'display_phone': '+1 416-298-3828',
#                  'distance': 4062.2764422047167,
#                  'id': '6f2imTsIysASgHh2t91OOQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5eYp5Mn2AfZmlE6BTEpFhA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '633 Silver Star Blvd',
#                               'address2': 'Unit 108',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'country': 'CA',
#                               'display_address': ['633 Silver Star Blvd',
#                                                   'Unit 108',
#                                                   'Toronto, ON M1V 5N1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'M1V 5N1'},
#                  'name': 'AKA-ONI Ramen&izakaya -Scarborough',
#                  'phone': '+14162983828',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 328,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/aka-oni-ramen-and-izakaya-scarborough-toronto?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'mabu-generation-markham',
#                  'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#                  'coordinates': {'latitude': 43.84872, 'longitude': -79.347935},
#                  'display_phone': '+1 905-604-8358',
#                  'distance': 2832.1887341065208,
#                  'id': 'Qayz6avNEPNS6Q5UThYHCQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zOndFphyZIPWGZLoxiXa0w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3235 Highway 7',
#                               'address2': 'Unit 23-26',
#                               'address3': None,
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['3235 Highway 7',
#                                                   'Unit 23-26',
#                                                   'Markham, ON L3R 3P3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 3P3'},
#                  'name': 'MABU Generation',
#                  'phone': '+19056048358',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 433,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mabu-generation-markham?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'comebuy-markham-2',
#                  'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#                  'coordinates': {'latitude': 43.8506667901241,
#                                  'longitude': -79.3256200220901},
#                  'display_phone': '+1 905-604-3699',
#                  'distance': 1125.1529487081643,
#                  'id': '0Ne8FCrcF1C018uihKjq-w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_Zye8LSENxLUWLXBFaR3NA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4-8110 Birchmount Road',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Markham',
#                               'country': 'CA',
#                               'display_address': ['4-8110 Birchmount Road',
#                                                   'Markham, ON L6G 0E3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L6G 0E3'},
#                  'name': 'Comebuy',
#                  'phone': '+19056043699',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 79,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/comebuy-markham-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'ambiyan-unionville',
#                  'categories': [{'alias': 'indpak', 'title': 'Indian'},
#                                 {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#                  'coordinates': {'latitude': 43.86632, 'longitude': -79.31114},
#                  'display_phone': '+1 905-480-0094',
#                  'distance': 1095.5437897938305,
#                  'id': '6mI2kt70hiOb0UaNYXfS8w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pGX69Vy9kKIku9TDmfOU9A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '149 Main Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Unionville',
#                               'country': 'CA',
#                               'display_address': ['149 Main Street',
#                                                   'Unionville, ON L3R 2G8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L3R 2G8'},
#                  'name': 'Ambiyan',
#                  'phone': '+19054800094',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 143,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ambiyan-unionville?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'}],
#  'region': {'center': {'latitude': 43.856765181089315,
#                        'longitude': -79.31442260742188}},
#  'total': 2700}

# %%
# Create empty lists to store the results
names = []
ratings = []
prices = []
categories = []
display_addresses = []
review_counts = []
latitudes = []
longitudes = []

# Loop through each business and extract the desired information
for business in Markham_data["businesses"]:
    names.append(business["name"])
    ratings.append(business["rating"])
    prices.append(business.get("price", "N/A"))
    categories.append(", ".join([category["title"] for category in business["categories"]]))
    display_addresses.append(", ".join(business["location"]["display_address"]))
    review_counts.append(business["review_count"])
    latitudes.append(business["coordinates"]["latitude"])
    longitudes.append(business["coordinates"]["longitude"])

# Create a dataframe from the extracted information
Markham_df = pd.DataFrame({
    "Name": names,
    "Rating": ratings,
    "Price": prices,
    "Categories": categories,
    "Address": display_addresses,
    "Reviews": review_counts,
    "Latitude": latitudes,
    "Longitude": longitudes
}, index=range(1, len(Markham_data["businesses"]) + 1))

# Print the dataframe
Markham_df.head()
# Out:
#                        Name  Rating Price  \
# 1       Smash Kitchen & Bar     4.0    $$
# 2       NextDoor Restaurant     4.0    $$
# 3            Alchemy Coffee     4.0    $$
# 4          Azyun Restaurant     4.0    $$
# 5  Ruth's Chris Steak House     4.0  $$$$
#
#                                       Categories  \
# 1  Comfort Food, American (Traditional), Seafood
# 2       Canadian (New), Bars, Tapas/Small Plates
# 3               Coffee & Tea, Breakfast & Brunch
# 4                            Chinese, Tapas Bars
# 5                  Steakhouses, Lounges, Seafood
#
#                                              Address  Reviews   Latitude  \
# 1   4261 Highway 7 E, Unionville, ON L3R 9W6, Canada      860  43.859120
# 2  139 Main Street Unionville, Markham, ON L3R 2G...      557  43.865400
# 3  4361 Highway 7 E, Unit 1, Markham, ON L3R 1M1,...      605  43.860537
# 4  144 Main Street N, Unit 17, Markham, ON L3P 5T...      257  43.878901
# 5   170 Enterprise Blvd, Markham, ON L6G 0E6, Canada      108  43.849553
#
#    Longitude
# 1 -79.314730
# 2 -79.310050
# 3 -79.312339
# 4 -79.261180
# 5 -79.324536

# %%
# Save the DataFrame 
Markham_df.to_csv('Markham.csv', index=False)

# %% [markdown]
# ## Take 50 samples in Mississauga

# %%
# Set the API base URL and endpoint
base_url = "https://api.yelp.com/v3"
endpoint = "/businesses/search"

headers = {
    "Authorization": f"Bearer {yelp_api_key}"
}

params = {
    "location": "Mississauga", 
    "offset": 0,
    "price": "1,2,3,4",
    "limit": 50  
}

response = requests.get(base_url + endpoint, headers=headers, params=params)
Mississauga_data = response.json()

pprint.pprint(Mississauga_data)
# Out:
# {'businesses': [{'alias': 'pho-ngoc-yen-restaurant-mississauga',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 43.638760740612305,
#                                  'longitude': -79.64369129581637},
#                  'display_phone': '+1 905-629-9559',
#                  'distance': 4074.1745645142755,
#                  'id': 'Itc-dI_qZ696GExH1iAuRQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QD0wqQfI6eB4FgpVdOXKXA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1090 Kamato Road',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['1090 Kamato Road',
#                                                   'Mississauga, ON L4W 2P3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L4W 2P3'},
#                  'name': 'Pho Ngoc Yen Restaurant',
#                  'phone': '+19056299559',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 459,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pho-ngoc-yen-restaurant-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'the-wilcox-gastropub-mississauga',
#                  'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 43.6060467626593,
#                                  'longitude': -79.6528506651521},
#                  'display_phone': '+1 905-568-1122',
#                  'distance': 2021.1924330253812,
#                  'id': 'Wc7Hld-DTJbss8CndeIylw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KFBlOtGrb11RVKbsQSLYGg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '30 Eglinton Avenue W',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['30 Eglinton Avenue W',
#                                                   'Mississauga, ON L5R 3E7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5R 3E7'},
#                  'name': 'The Wilcox Gastropub',
#                  'phone': '+19055681122',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 356,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-wilcox-gastropub-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'ricks-good-eats-mississauga',
#                  'categories': [{'alias': 'indpak', 'title': 'Indian'},
#                                 {'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 43.64849814518965,
#                                  'longitude': -79.68609655576972},
#                  'display_phone': '+1 905-696-6966',
#                  'distance': 4218.780981504023,
#                  'id': 'KPSaUzlYg4JLVbzrbA23uw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XDR2kjXJjLzyA6haQP4XTQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6660 Kennedy Road',
#                               'address2': 'Unit 1',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['6660 Kennedy Road',
#                                                   'Unit 1',
#                                                   'Mississauga, ON L5T 2V3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5T 2V3'},
#                  'name': "Rick's Good Eats",
#                  'phone': '+19056966966',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 400,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ricks-good-eats-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'the-maharaja-mississauga-2',
#                  'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#                  'coordinates': {'latitude': 43.59939, 'longitude': -79.66033},
#                  'display_phone': '+1 905-507-2444',
#                  'distance': 1915.5014516517604,
#                  'id': '-iauwrCGxk1cEJJnf4soTg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lq7Hruey2SN5VJ60a3nvYg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4646 Heritage Hills Boulevard',
#                               'address2': 'Unit 3',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['4646 Heritage Hills '
#                                                   'Boulevard',
#                                                   'Unit 3',
#                                                   'Mississauga, ON L5R 1Y3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5R 1Y3'},
#                  'name': 'The Maharaja',
#                  'phone': '+19055072444',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 155,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-maharaja-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'gyubee-japanese-grill-mississauga-mississauga-2',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 43.6045973,
#                                  'longitude': -79.6494211},
#                  'display_phone': '+1 905-507-6228',
#                  'distance': 2227.4772752215285,
#                  'id': 'AZwb5zL-5-7_I7muscc_9A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ozp274jhWNk14fvjQcr1ow/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4559 Hurontario St',
#                               'address2': 'Unit A2',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['4559 Hurontario St',
#                                                   'Unit A2',
#                                                   'Mississauga, ON L4Z 3L9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L4Z 3L9'},
#                  'name': 'Gyubee Japanese Grill - Mississauga',
#                  'phone': '+19055076228',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 124,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gyubee-japanese-grill-mississauga-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'scaddabush-mississauga-2',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'},
#                                 {'alias': 'beer_and_wine',
#                                  'title': 'Beer, Wine & Spirits'}],
#                  'coordinates': {'latitude': 43.5933827,
#                                  'longitude': -79.64876401},
#                  'display_phone': '+1 905-281-1721',
#                  'distance': 3008.2033775046034,
#                  'id': 'MrmwDgMlL2GtthlAZsJwNQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9LmJUfSEvqzmKZb-akWUSg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '209 Rathburn Road West',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['209 Rathburn Road West',
#                                                   'Mississauga, ON L5B 4E5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5B 4E5'},
#                  'name': 'Scaddabush',
#                  'phone': '+19052811721',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 437,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/scaddabush-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'union-social-eatery-mississauga',
#                  'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 43.6112458,
#                                  'longitude': -79.7490723},
#                  'display_phone': '+1 905-814-1234',
#                  'distance': 5884.941181055324,
#                  'id': 'w1clLiXOo-yLhNjt5jDBCA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cOzqSVwqj9mRdFEQmlqq-w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6986 Financial Drive',
#                               'address2': 'Unit 6',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['6986 Financial Drive',
#                                                   'Unit 6',
#                                                   'Mississauga, ON L5N 8J4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5N 8J4'},
#                  'name': 'Union Social Eatery',
#                  'phone': '+19058141234',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 392,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/union-social-eatery-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'guru-lukshmi-mississauga-4',
#                  'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#                  'coordinates': {'latitude': 43.6393317020495,
#                                  'longitude': -79.7159669611217},
#                  'display_phone': '+1 905-795-2299',
#                  'distance': 4437.340594450046,
#                  'id': 'LI9sVHgnX-DzFyvWmPDRgA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cl8stNhAxaXp8uiXyrXSZg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7070 St Barbara Boulevard',
#                               'address2': 'Unit 45 & 50',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['7070 St Barbara Boulevard',
#                                                   'Unit 45 & 50',
#                                                   'Mississauga, ON L5W 0E6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5W 0E6'},
#                  'name': 'Guru Lukshmi',
#                  'phone': '+19057952299',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 569,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/guru-lukshmi-mississauga-4?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'alioli-ristorante-mississauga',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 43.5852, 'longitude': -79.644006},
#                  'display_phone': '+1 905-281-1122',
#                  'distance': 3918.798129285245,
#                  'id': 'yxQsedCcjJEfqhC7u8Rl0A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BjPeh9ecYxstf_X6VeS7LQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '350 Burnhamthorpe Road W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['350 Burnhamthorpe Road W',
#                                                   'Mississauga, ON L5B 3J1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5B 3J1'},
#                  'name': 'Alioli Ristorante',
#                  'phone': '+19052811122',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 122,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/alioli-ristorante-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'the-keg-steakhouse-bar-mississauga-11',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 43.609511,
#                                  'longitude': -79.689827},
#                  'display_phone': '+1 905-502-0002',
#                  'distance': 1043.6788819234616,
#                  'id': 'd8DecPaXGgv-jFYQeGCXUg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VK2RrIaBAMpSZ_6N_sLYOg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '670 Matheson Boulevard W',
#                               'address2': '',
#                               'address3': 'Heartland Town Centre',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['670 Matheson Boulevard W',
#                                                   'Heartland Town Centre',
#                                                   'Mississauga, ON L5R 3T2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5R 3T2'},
#                  'name': 'The Keg Steakhouse + Bar',
#                  'phone': '+19055020002',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 99,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-keg-steakhouse-bar-mississauga-11?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'watan-kabob-mississauga',
#                  'categories': [{'alias': 'afghani', 'title': 'Afghan'}],
#                  'coordinates': {'latitude': 43.6199294,
#                                  'longitude': -79.6692718},
#                  'display_phone': '+1 905-712-2221',
#                  'distance': 1183.2367048260794,
#                  'id': 'Eu-M3y8a5bIxIRXlCj9yHA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2zSSlLBTbvBRF2FTt9gkpw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '55 Matheson Boulevard E',
#                               'address2': 'Unit 2',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['55 Matheson Boulevard E',
#                                                   'Unit 2',
#                                                   'Mississauga, ON L4Z 1X8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L4Z 1X8'},
#                  'name': 'Watan Kabob',
#                  'phone': '+19057122221',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 221,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/watan-kabob-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'miga-korean-bbq-restaurant-mississauga-2',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'korean', 'title': 'Korean'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 43.5293729514098,
#                                  'longitude': -79.6734766202265},
#                  'display_phone': '+1 905-822-9200',
#                  'distance': 9096.360970278296,
#                  'id': 'IKRh-Kzh2UExFGif5zoiFw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FWHkvQEEE-AxqzV00HZc7A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2382 Dundas Street W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['2382 Dundas Street W',
#                                                   'Mississauga, ON L5K 1R7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5K 1R7'},
#                  'name': 'Miga Korean BBQ Restaurant',
#                  'phone': '+19058229200',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 306,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/miga-korean-bbq-restaurant-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'katsuya-mississauga-4',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 43.5539042328967,
#                                  'longitude': -79.6453385342378},
#                  'display_phone': '+1 905-277-2242',
#                  'distance': 6854.728396428,
#                  'id': '7P9pfy7Lp7aH_Arh1OMOAA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O-V55_DPxCjNy4p5GN231Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1224 Dundas Street W',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['1224 Dundas Street W',
#                                                   'Mississauga, ON L5C 4G7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5C 4G7'},
#                  'name': 'Katsuya',
#                  'phone': '+19052772242',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 175,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/katsuya-mississauga-4?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'panagios-all-day-grill-mississauga',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 43.59987806058704,
#                                  'longitude': -79.71270469597843},
#                  'display_phone': '+1 905-812-2229',
#                  'distance': 3139.482670276659,
#                  'id': 'D7e_2VZ2vcVhrhhgaIUluA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/61f-13gB6988fRgBRcORGw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6085 Creditview Road',
#                               'address2': 'Unit 17',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['6085 Creditview Road',
#                                                   'Unit 17',
#                                                   'Mississauga, ON L5V 2A8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5V 2A8'},
#                  'name': "Panagio's All Day Grill",
#                  'phone': '+19058122229',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 141,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/panagios-all-day-grill-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'chilli-chicken-house-mississauga',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'indpak', 'title': 'Indian'}],
#                  'coordinates': {'latitude': 43.5681923545558,
#                                  'longitude': -79.666453152895},
#                  'display_phone': '+1 905-232-1199',
#                  'distance': 4849.780768171119,
#                  'id': '0v8icS8wOOgEDiHDCOQkZQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7efxmxdYml5snppHfEvf9A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4040 Creditview Road',
#                               'address2': 'Unit 25',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['4040 Creditview Road',
#                                                   'Unit 25',
#                                                   'Mississauga, ON L5C',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5C'},
#                  'name': 'Chilli Chicken House',
#                  'phone': '+19052321199',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 416,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chilli-chicken-house-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'congee-queen-mississauga',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 43.6120338404311,
#                                  'longitude': -79.6992362075354},
#                  'display_phone': '+1 905-567-8818',
#                  'distance': 1797.0552012355279,
#                  'id': 'E7eOOXwMC7wwCRywsvNzUA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rjP9bU5MwnGJa3GTLrpMZg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '800 Boyer Boulevard',
#                               'address2': 'Unit 5',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['800 Boyer Boulevard',
#                                                   'Unit 5',
#                                                   'Mississauga, ON L5V 2Y1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5V 2Y1'},
#                  'name': 'Congee Queen',
#                  'phone': '+19055678818',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 259,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/congee-queen-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'twin-fish-thai-cuisine-mississauga',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 43.6382184,
#                                  'longitude': -79.6927568},
#                  'display_phone': '+1 905-670-2395',
#                  'distance': 3115.0857322202123,
#                  'id': 'zWOFKsBDFTYfU4Mp6lONTA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vGGZOwZrMhsTRLKYxVqDQQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '80 Courtneypark Drive E',
#                               'address2': 'Unit K2',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['80 Courtneypark Drive E',
#                                                   'Unit K2',
#                                                   'Mississauga, ON L5T 2Y3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5T 2Y3'},
#                  'name': 'Twin Fish Thai Cuisine',
#                  'phone': '+19056702395',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 229,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/twin-fish-thai-cuisine-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'avani-asian-indian-bistro-mississauga-2',
#                  'categories': [{'alias': 'indpak', 'title': 'Indian'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 43.60632743859953,
#                                  'longitude': -79.69189471166078},
#                  'display_phone': '+1 905-501-0021',
#                  'distance': 1316.9283540132876,
#                  'id': '2t-a8qkgoRiiohThDVjfNw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9BOklFqz-CKojAdsJ3-D6g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '801 Matheson Boulevard W',
#                               'address2': 'Unit 1',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['801 Matheson Boulevard W',
#                                                   'Unit 1',
#                                                   'Mississauga, ON L5V 2N6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5V 2N6'},
#                  'name': 'Avani Asian Indian Bistro',
#                  'phone': '+19055010021',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 304,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/avani-asian-indian-bistro-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'daddy-o-doughnuts-and-british-baked-goods-mississauga',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'donuts', 'title': 'Donuts'}],
#                  'coordinates': {'latitude': 43.5818131148229,
#                                  'longitude': -79.5861366020917},
#                  'display_phone': '+1 905-276-9090',
#                  'distance': 8007.146077453761,
#                  'id': 'cLPv_OR49siI6QVvN4g6Ew',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Uuq0YFnCYxJ_EMYoOr-KAQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '589 N Service Road',
#                               'address2': 'Unit 5',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['589 N Service Road',
#                                                   'Unit 5',
#                                                   'Mississauga, ON L5A 1B2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5A 1B2'},
#                  'name': 'Daddy O Doughnuts and British Baked Goods',
#                  'phone': '+19052769090',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 153,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/daddy-o-doughnuts-and-british-baked-goods-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'huevos-gourmet-mississauga',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 43.55929, 'longitude': -79.57699},
#                  'display_phone': '',
#                  'distance': 9902.506583524399,
#                  'id': 'ufwkkMd9yr9cFU1R5ONArg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bCeKpVtlsPf7ygYvBz2Lrw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '241 Lakeshore Road',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['241 Lakeshore Road',
#                                                   'Mississauga, ON L5G 1G8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5G 1G8'},
#                  'name': 'Huevos Gourmet',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 243,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/huevos-gourmet-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'cagneys-steakhouse-and-wine-bar-mississauga',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 43.58265, 'longitude': -79.71752},
#                  'display_phone': '+1 905-826-2311',
#                  'distance': 4550.795033706281,
#                  'id': 'FLtVhfTaYIz0C7AsU6KOuw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I9_HbY6i36g8E-WllcbhEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '128 Queen Street S',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['128 Queen Street S',
#                                                   'Mississauga, ON L5M 1K8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5M 1K8'},
#                  'name': 'Cagneys Steakhouse & Wine Bar',
#                  'phone': '+19058262311',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 127,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/cagneys-steakhouse-and-wine-bar-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'culinaria-restaurant-mississauga',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 43.6310117,
#                                  'longitude': -79.6620767},
#                  'display_phone': '+1 905-890-7330',
#                  'distance': 2513.1122497810156,
#                  'id': 'DJTp8_qFr1mU_HMvvhk8Bw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sf7eNWvMfcdOXf2RLW4rLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5732 Kennedy Road',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['5732 Kennedy Road',
#                                                   'Mississauga, ON L4Z 1T1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L4Z 1T1'},
#                  'name': 'Culinaria Restaurant',
#                  'phone': '+19058907330',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 29,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/culinaria-restaurant-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'samara-kitchen-mississauga',
#                  'categories': [{'alias': 'indonesian', 'title': 'Indonesian'}],
#                  'coordinates': {'latitude': 43.6490393766877,
#                                  'longitude': -79.6559201180935},
#                  'display_phone': '+1 647-772-3130',
#                  'distance': 4541.39224139876,
#                  'id': 'aN6iNDuc1W1z_1evSKUECA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dMH8wF6qxn6CIl3jLjzwag/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '13-6033 Shawson Drive',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['13-6033 Shawson Drive',
#                                                   'Mississauga, ON L5T 1E7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5T 1E7'},
#                  'name': 'Samara Kitchen',
#                  'phone': '+16477723130',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 47,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/samara-kitchen-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'sushi-omigoto-mississauga',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'korean', 'title': 'Korean'}],
#                  'coordinates': {'latitude': 43.59714220385148,
#                                  'longitude': -79.5944882781007},
#                  'display_phone': '+1 905-275-5566',
#                  'distance': 6819.625687635503,
#                  'id': 'SPKNsdqFSI3kp5EMKyC0Mw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9c1XxMeeSgJcE0ejEyv5Xg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'E1 - 888 Dundas Street E',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['E1 - 888 Dundas Street E',
#                                                   'Mississauga, ON L4Y 4G6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L4Y 4G6'},
#                  'name': 'Sushi Omigoto',
#                  'phone': '+19052755566',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 190,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sushi-omigoto-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'reds-mississauga-2',
#                  'categories': [{'alias': 'venues',
#                                  'title': 'Venues & Event Spaces'},
#                                 {'alias': 'argentine', 'title': 'Argentine'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 43.593752,
#                                  'longitude': -79.643242},
#                  'display_phone': '+1 905-270-9090',
#                  'distance': 3332.3683467054457,
#                  'id': 'uVyrgJMqfmzwzDIK465DJg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F3H4Z5bMGStTvpRmU9JqlQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '100 City Centre Drive',
#                               'address2': 'Unit #2-815, Square One',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['100 City Centre Drive',
#                                                   'Unit #2-815, Square One',
#                                                   'Mississauga, ON L5B 2C9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5B 2C9'},
#                  'name': 'Reds',
#                  'phone': '+19052709090',
#                  'price': '$$$',
#                  'rating': 3.5,
#                  'review_count': 149,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/reds-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'masrawy-egyptian-kitchen-mississauga-2',
#                  'categories': [{'alias': 'egyptian', 'title': 'Egyptian'}],
#                  'coordinates': {'latitude': 43.58315086687568,
#                                  'longitude': -79.72881850205233},
#                  'display_phone': '+1 647-654-4444',
#                  'distance': 5208.914916080951,
#                  'id': '6iIH4r_thzKEKH7Qmeulcw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NLkjNT49bqcmI46I0TypKA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2275 Britannia Rd W',
#                               'address2': 'Unit 1',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['2275 Britannia Rd W',
#                                                   'Unit 1',
#                                                   'Mississauga, ON L5M 2G6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5M 2G6'},
#                  'name': 'Masrawy Egyptian Kitchen',
#                  'phone': '+16476544444',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 137,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/masrawy-egyptian-kitchen-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'takumi-bbq-and-ramen-mississauga',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 43.5689876885603,
#                                  'longitude': -79.6628097072244},
#                  'display_phone': '+1 905-896-1170',
#                  'distance': 4823.454016843869,
#                  'id': 'qxmJlT8UAn63qiHQRrgwXg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nmXi8kZJjBOWNLAKJryzdQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1170 Burnhamthorpe Road W',
#                               'address2': 'Unit 12',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['1170 Burnhamthorpe Road W',
#                                                   'Unit 12',
#                                                   'Mississauga, ON L5C 4E6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5C 4E6'},
#                  'name': 'Takumi BBQ and Ramen',
#                  'phone': '+19058961170',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 61,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/takumi-bbq-and-ramen-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'raw-aura-mississauga',
#                  'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#                                 {'alias': 'raw_food', 'title': 'Live/Raw Food'},
#                                 {'alias': 'gluten_free',
#                                  'title': 'Gluten-Free'}],
#                  'coordinates': {'latitude': 43.5535, 'longitude': -79.58421},
#                  'display_phone': '+1 905-891-2872',
#                  'distance': 9853.838789987669,
#                  'id': 'AprsB5kibAxqt77MeCPy6g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BgmwNaMUhr-DBdHBHtoyzg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '94 Lakeshore Rd E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['94 Lakeshore Rd E',
#                                                   'Mississauga, ON L5G 1E3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5G 1E3'},
#                  'name': 'Raw Aura',
#                  'phone': '+19058912872',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 143,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/raw-aura-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'shawarnado-mississauga-2',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'}],
#                  'coordinates': {'latitude': 43.62577, 'longitude': -79.62935},
#                  'display_phone': '+1 905-624-0001',
#                  'distance': 4167.21670091141,
#                  'id': 'LyhorVKqszgnvM6R29eOAg',
# ...
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['730 Matheson Boulevard West',
#                                                   'Mississauga, ON L5R 3T2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5R 3T2'},
#                  'name': 'Milestones',
#                  'phone': '+19055074118',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 67,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/milestones-mississauga-3?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'pane-e-vino-ristorante-mississauga-4',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 43.62837, 'longitude': -79.67358},
#                  'display_phone': '+1 905-502-5656',
#                  'distance': 1950.2845228904519,
#                  'id': '1v4kXcATiOFPLZMVkMU0Ow',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n5cLU0p78gIuMOxEQhI5Ow/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '151 Brunel Road',
#                               'address2': 'Unit 14 & 15',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['151 Brunel Road',
#                                                   'Unit 14 & 15',
#                                                   'Mississauga, ON L4Z 2H6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L4Z 2H6'},
#                  'name': 'Pane E Vino Ristorante',
#                  'phone': '+19055025656',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 26,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pane-e-vino-ristorante-mississauga-4?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'la-carnita-mississauga',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 43.593078609238,
#                                  'longitude': -79.6424909681082},
#                  'display_phone': '+1 905-766-1947',
#                  'distance': 3425.1771105724724,
#                  'id': 'NOMxEkVNM9Q0vPIMiI6qZQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xKbAsBPSBXc6LXa5JuDEoA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '100 City Centre Drive',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['100 City Centre Drive',
#                                                   'Mississauga, ON L5B 2C9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5B 2C9'},
#                  'name': 'La Carnita',
#                  'phone': '+19057661947',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 99,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/la-carnita-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'jollibee-mississauga-2',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'chickenshop',
#                                  'title': 'Chicken Shop'}],
#                  'coordinates': {'latitude': 43.612424579122774,
#                                  'longitude': -79.69970762533904},
#                  'display_phone': '+1 289-203-4555',
#                  'distance': 1837.8113903036265,
#                  'id': 'ae7CKGtzjmSIlNKhAjMxKg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nmZQDMkEOB9mwYvhJDzODg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '800 Boyer Boulevard',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['800 Boyer Boulevard',
#                                                   'Mississauga, ON L5V 1Y1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5V 1Y1'},
#                  'name': 'Jollibee',
#                  'phone': '+12892034555',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 129,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jollibee-mississauga-2?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'basil-box-mississauga-5',
#                  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                                 {'alias': 'thai', 'title': 'Thai'},
#                                 {'alias': 'gluten_free',
#                                  'title': 'Gluten-Free'}],
#                  'coordinates': {'latitude': 43.5928749,
#                                  'longitude': -79.6430241},
#                  'display_phone': '+1 905-277-3000',
#                  'distance': 3403.965619908028,
#                  'id': 'cwQwLJMaTA2Zm0LfPx4diw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/w09XxP1Cb2jHcLGRzaKOSw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '100 City Centre Drive',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['100 City Centre Drive',
#                                                   'Mississauga, ON L5B 2C9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5B 2C9'},
#                  'name': 'Basil Box',
#                  'phone': '+19052773000',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 85,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/basil-box-mississauga-5?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'goodfellas-pizza-mississauga',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 43.58138, 'longitude': -79.71286},
#                  'display_phone': '+1 855-433-5527',
#                  'distance': 4399.5849048314985,
#                  'id': 'w2IE4nbufBqwrub7CW80xg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fhg3e6oatrrLlFeG-pN9KA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '209 Queen Street S',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['209 Queen Street S',
#                                                   'Mississauga, ON L5M 1X3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5M 1X3'},
#                  'name': 'Goodfellas Pizza',
#                  'phone': '+18554335527',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 353,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/goodfellas-pizza-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'peters-on-eglinton-mississauga',
#                  'categories': [{'alias': 'fishnchips',
#                                  'title': 'Fish & Chips'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'delis', 'title': 'Delis'}],
#                  'coordinates': {'latitude': 43.62888, 'longitude': -79.62925},
#                  'display_phone': '+1 905-624-1995',
#                  'distance': 4317.869302942763,
#                  'id': 'hE5x9T5Al5fL7diXhOcgng',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8SR8eQVWtbeMy_UjnuFkWA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1035 Eglinton Avenue E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['1035 Eglinton Avenue E',
#                                                   'Mississauga, ON L4W 1K4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L4W 1K4'},
#                  'name': "Peter's On Eglinton",
#                  'phone': '+19056241995',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 156,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/peters-on-eglinton-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'lazar-famous-deli-and-bakery-mississauga',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'customcakes',
#                                  'title': 'Custom Cakes'},
#                                 {'alias': 'delis', 'title': 'Delis'}],
#                  'coordinates': {'latitude': 43.58261, 'longitude': -79.63842},
#                  'display_phone': '+1 905-896-1040',
#                  'distance': 4440.836767140699,
#                  'id': 'k1q6ArrSV2Z_Yodwu4epVg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ipu6ER12tKiijQA0DJbedg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '12-325 Central Parkway W',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['12-325 Central Parkway W',
#                                                   'Mississauga, ON L5B 3X9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5B 3X9'},
#                  'name': 'Lazar Famous Deli & Bakery',
#                  'phone': '+19058961040',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 85,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/lazar-famous-deli-and-bakery-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'moxies-mississauga-9',
#                  'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#                                 {'alias': 'lounges', 'title': 'Lounges'}],
#                  'coordinates': {'latitude': 43.60098, 'longitude': -79.7411},
#                  'display_phone': '+1 905-812-2467',
#                  'distance': 5287.201943600552,
#                  'id': 'lxunwc4AHLJ_MaDVRlUyEw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/38FFMT_tsw-6Dug9X0qLYg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2001 Argentia Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['2001 Argentia Rd',
#                                                   'Mississauga, ON L5N 2L3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5N 2L3'},
#                  'name': 'Moxies',
#                  'phone': '+19058122467',
#                  'price': '$$$',
#                  'rating': 3.5,
#                  'review_count': 144,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/moxies-mississauga-9?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'},
#                 {'alias': 'the-food-district-mississauga',
#                  'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#                                 {'alias': 'cookingclasses',
#                                  'title': 'Cooking Classes'}],
#                  'coordinates': {'latitude': 43.59474, 'longitude': -79.64068},
#                  'display_phone': '+1 905-270-7771',
#                  'distance': 3331.320123497943,
#                  'id': '-2FD5ANi-Hs6qEhYqsQLaQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pET_DSm2MeDc3IOoQr5mKg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '100 City Centre Drive',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mississauga',
#                               'country': 'CA',
#                               'display_address': ['100 City Centre Drive',
#                                                   'Mississauga, ON L5B 2C9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'L5B 2C9'},
#                  'name': 'The Food District',
#                  'phone': '+19052707771',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 35,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-food-district-mississauga?adjust_creative=KdtETl0LO0crYqgmXmhE2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KdtETl0LO0crYqgmXmhE2w'}],
#  'region': {'center': {'latitude': 43.61103753057372,
#                        'longitude': -79.67697143554688}},
#  'total': 1500}

# %%
# Create empty lists to store the results
names = []
ratings = []
prices = []
categories = []
display_addresses = []
review_counts = []
latitudes = []
longitudes = []

# Loop through each business and extract the desired information
for business in Mississauga_data["businesses"]:
    names.append(business["name"])
    ratings.append(business["rating"])
    prices.append(business.get("price", "N/A"))
    categories.append(", ".join([category["title"] for category in business["categories"]]))
    display_addresses.append(", ".join(business["location"]["display_address"]))
    review_counts.append(business["review_count"])
    latitudes.append(business["coordinates"]["latitude"])
    longitudes.append(business["coordinates"]["longitude"])

# Create a dataframe from the extracted information
Mississauga_df = pd.DataFrame({
    "Name": names,
    "Rating": ratings,
    "Price": prices,
    "Categories": categories,
    "Address": display_addresses,
    "Reviews": review_counts,
    "Latitude": latitudes,
    "Longitude": longitudes
}, index=range(1, len(Mississauga_data["businesses"]) + 1))

# Print the dataframe
Mississauga_df.head()
# Out:
#                                   Name  Rating Price  \
# 1              Pho Ngoc Yen Restaurant     4.5    $$
# 2                 The Wilcox Gastropub     4.0    $$
# 3                     Rick's Good Eats     4.5    $$
# 4                         The Maharaja     4.0   $$$
# 5  Gyubee Japanese Grill - Mississauga     4.5   $$$
#
#                                       Categories  \
# 1                                     Vietnamese
# 2  Gastropubs, Breakfast & Brunch, Cocktail Bars
# 3                         Indian, Canadian (New)
# 4                                         Indian
# 5                             Japanese, Barbeque
#
#                                              Address  Reviews   Latitude  \
# 1  1090 Kamato Road, Mississauga, ON L4W 2P3, Canada      459  43.638761
# 2  30 Eglinton Avenue W, Mississauga, ON L5R 3E7,...      356  43.606047
# 3  6660 Kennedy Road, Unit 1, Mississauga, ON L5T...      400  43.648498
# 4  4646 Heritage Hills Boulevard, Unit 3, Mississ...      155  43.599390
# 5  4559 Hurontario St, Unit A2, Mississauga, ON L...      124  43.604597
#
#    Longitude
# 1 -79.643691
# 2 -79.652851
# 3 -79.686097
# 4 -79.660330
# 5 -79.649421

# %%
# Save the DataFrame 
Mississauga_df.to_csv('Mississauga.csv', index=False)
